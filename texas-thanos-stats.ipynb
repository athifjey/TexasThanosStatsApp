# %% [markdown]
# # 🏏 Texas Thanos Stats
# Use the code cell below to render the Texas Thanos Stats dashboard with live Google Sheets data.

# %%
from IPython.display import display

# Emits output using the custom mime type registered by this extension.
display({"x-application/texas-thanos-stats": []}, raw=True)
